# %% [markdown]
# <a href="https://colab.research.google.com/github/every1218/Deep-Learning/blob/main/Linear_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
imp
ort matplotlib.pyplot as plt

x = torch.tensor([150, 160, 170, 175, 185.]) # 키
y = torch.tensor([55, 70, 64, 80, 75.]) # 몸무게
N = len(x)
plt.plot(x,y,'o')

# %%
# 초깃값 설정
a = 0.45
b = -35
x_plot=torch.linspace(145,190,100)
y_plot=a * x_plot + b

plt.plot(x,y,'o')
plt.plot(x_plot,y_plot,'r')

# %%
# a,b 를 바꿔가면서 Loss 값을 일일히 구해서 가장 작아지게 하는 a,b를 선정

a = 0.5 + torch.linspace(-0.2,0.2,100)
b = -30 + torch.linspace(-20,20,100)

L=torch.zeros(len(a),len(b))
for i in range(len(a)):
    for j in range(len(b)):
        for n in range(N):
            L[i,j] = L[i,j] + (y[n] - (a[i]*x[n]+b[j]))**2
L = L/N # MSE

#📈 3D 그래프: Loss Surface
#a축, b축, Loss 값으로 그래프 생성 → 어디에서 Loss가 가장 작은지 보려고
plt.figure(figsize=[6, 4])
ax = plt.axes(projection="3d")
A, B = torch.meshgrid(a,b)
ax.plot_surface(A,B,L);
ax.set_xlabel('a'); ax.set_ylabel('b')
ax.set_zlim([0, 1000])

#🗺 2D 등고선: Contour Map
plt.figure(figsize=[6, 4])
plt.contour(b,a,L,30)
plt.plot(-25.76, 0.5626, 'ro')  # 최적점 찍기
plt.xlabel('b'); plt.ylabel('a'); plt.grid()

# %%
plt.contourf(b, a, L, 30, cmap='viridis')
plt.plot(-25.76, 0.5626, 'ro')  # 최적점 찍기
plt.colorbar()

# %%
print(torch.min(L))
a_opt = A[L==torch.min(L)]
b_opt = B[L==torch.min(L)]
print(f"optimal a = {a_opt}")
print(f"optimal b = {b_opt}")
# Out:
# tensor(29.0315)
# optimal a = tensor([0.5626])
# optimal b = tensor([-25.7576])

# %%
x_plot=torch.linspace(145,190,100)
y_plot=a_opt * x_plot + b_opt
plt.plot(x,y,'o')
plt.plot(x_plot,y_plot,'r')

# %%
import plotly.graph_objects as go
fig = go.Figure(data=[go.Surface(x=b, y=a, z=L, colorscale="viridis", opacity=0.5)])
fig.update_traces(contours_z=dict(show=True, usecolormap=True, highlightcolor="limegreen", project_z=True))
fig.update_layout(title='Loss', width=700, height=600,
                  scene = dict( xaxis_title='b', yaxis_title='a', zaxis_title='Loss', zaxis=dict(nticks=20, range=[0,1000]) ))
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="398f4f38-d098-48e6-a5f0-12f17f96eac1" class="plotly-graph-div" style="height:600px; width:700px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("398f4f38-d098-48e6-a5f0-12f17f96eac1")) {                    Plotly.newPlot(                        "398f4f38-d098-48e6-a5f0-12f17f96eac1",                        [{"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"opacity":0.5,"x":[-50.0,-49.59596,-49.191917,-48.78788,-48.38384,-47.979797,-47.57576,-47.171715,-46.767677,-46.363636,-45.959595,-45.555557,-45.151516,-44.747475,-44.343433,-43.939392,-43.535355,-43.131313,-42.727272,-42.323235,-41.919193,-41.515152,-41.11111,-40.70707,-40.303032,-39.89899,-39.49495,-39.090908,-38.686867,-38.28283,-37.878788,-37.474747,-37.07071,-36.666668,-36.262627,-35.858585,-35.454544,-35.050507,-34.646465,-34.242424,-33.838383,-33.434345,-33.030304,-32.626263,-32.22222,-31.818182,-31.414143,-31.010101,-30.60606,-30.20202,-29.79798,-29.39394,-28.989899,-28.585857,-28.181818,-27.777777,-27.373737,-26.969696,-26.565657,-26.161615,-25.757576,-25.353535,-24.949495,-24.545454,-24.141415,-23.737373,-23.333332,-22.929293,-22.525253,-22.121212,-21.71717,-21.313131,-20.909092,-20.50505,-20.10101,-19.69697,-19.292929,-18.88889,-18.484848,-18.080807,-17.676767,-17.272728,-16.868687,-16.464645,-16.060606,-15.656566,-15.252525,-14.848485,-14.444445,-14.040404,-13.636364,-13.232323,-12.828283,-12.424242,-12.020203,-11.616161,-11.212122,-10.808081,-10.404041,-10.0],"y":[0.3,0.3040404,0.3080808,0.3121212,0.31616163,0.32020202,0.3242424,0.32828283,0.33232322,0.3363636,0.34040403,0.34444445,0.34848484,0.35252523,0.35656565,0.36060607,0.36464646,0.36868685,0.37272727,0.3767677,0.3808081,0.38484848,0.3888889,0.3929293,0.3969697,0.4010101,0.40505052,0.4090909,0.4131313,0.41717172,0.42121214,0.42525253,0.42929292,0.43333334,0.43737376,0.44141415,0.44545454,0.44949496,0.45353535,0.45757577,0.46161616,0.46565658,0.46969697,0.4737374,0.47777778,0.4818182,0.4858586,0.489899,0.4939394,0.4979798,0.5020202,0.5060606,0.510101,0.5141414,0.5181818,0.5222222,0.52626264,0.530303,0.5343434,0.53838384,0.54242426,0.5464646,0.55050504,0.55454546,0.5585859,0.56262624,0.56666666,0.5707071,0.57474744,0.57878786,0.5828283,0.5868687,0.59090906,0.5949495,0.5989899,0.6030303,0.6070707,0.6111111,0.6151515,0.6191919,0.6232323,0.6272727,0.63131315,0.63535357,0.6393939,0.64343435,0.64747477,0.6515151,0.65555555,0.65959597,0.6636364,0.6676768,0.67171717,0.6757576,0.679798,0.68383837,0.6878788,0.6919192,0.69595957,0.7],"z":[[4717.9,4662.79,4608.007,4553.551,4499.4204,4445.6177,4392.1406,4338.9893,4286.1655,4233.668,4181.497,4129.6533,4078.1353,4026.9429,3976.0781,3925.5398,3875.3281,3825.4426,3775.8828,3726.651,3677.7446,3629.1653,3580.912,3532.985,3485.3855,3438.112,3391.1648,3344.5442,3298.25,3252.2827,3206.6416,3161.3271,3116.339,3071.6775,3027.3425,2983.3337,2939.6516,2896.2964,2853.267,2810.5647,2768.1882,2726.1392,2684.416,2643.019,2601.9487,2561.2056,2520.7886,2480.698,2440.9338,2401.4963,2362.385,2323.6006,2285.142,2247.0105,2209.2056,2171.7268,2134.575,2097.749,2061.25,2025.0774,1989.2314,1953.7115,1918.5186,1883.652,1849.1117,1814.8981,1781.011,1747.4502,1714.2161,1681.3086,1648.7272,1616.4724,1584.5446,1552.9427,1521.6675,1490.719,1460.0967,1429.801,1399.8318,1370.1892,1340.873,1311.8834,1283.2201,1254.8833,1226.8732,1199.1896,1171.8323,1144.8015,1118.0974,1091.7197,1065.6683,1039.9436,1014.54553,989.4738,964.72864,940.30975,916.21765,892.45184,869.0127,845.8998],[4625.1914,4570.6304,4516.3955,4462. ...

# %%
# 모델 파라미터 초기화
a = torch.tensor([0.45], requires_grad=True)
b = torch.tensor([-35.], requires_grad=True)

# 하이퍼파라미터 설정
LR = 3e-6
EPOCH = 20

loss_history = []

for ep in range(EPOCH):
    # inference
    y_hat = a * x + b
    # loss
    loss = 0
    for n in range(N):
        loss += (y[n] - y_hat[n])**2
    loss = loss/N # MSE
    # update
    loss.backward() # backpropagation
    with torch.no_grad():
        a -= LR * a.grad # weight update
        b -= LR * b.grad # weight update
    a.grad = torch.tensor([0.]) # gradient 초기화
    b.grad = torch.tensor([0.]) # gradient 초기화
    # print loss
    loss_history += [loss.item()]
    print(f"Epoch: {ep+1}, train loss: {loss.item():.4f}")
    # print weight and bias
    print(f"Weight: {a.item():.4f}, Bias: {b.item():.4f}")
    # plot graph
    x_plot = torch.linspace(145, 190, 100)
    y_plot = a.detach() * x_plot + b.detach()
    plt.figure()
    plt.plot(x, y, 'o')
    plt.plot(x_plot, y_plot, 'r')
    plt.title(f"Epoch {ep+1}")
    plt.show()

    print("-"*20)
# Out:
# Epoch: 1, train loss: 826.2250
# Weight: 0.4785, Bias: -34.9998
# --------------------
# Epoch: 2, train loss: 578.0414
# Weight: 0.5022, Bias: -34.9997
# --------------------
# Epoch: 3, train loss: 407.1602
# Weight: 0.5218, Bias: -34.9996
# --------------------
# Epoch: 4, train loss: 289.5042
# Weight: 0.5381, Bias: -34.9995
# --------------------
# Epoch: 5, train loss: 208.4954
# Weight: 0.5517, Bias: -34.9994
# --------------------
# Epoch: 6, train loss: 152.7187
# Weight: 0.5629, Bias: -34.9993
# --------------------
# Epoch: 7, train loss: 114.3153
# Weight: 0.5722, Bias: -34.9993
# --------------------
# Epoch: 8, train loss: 87.8735
# Weight: 0.5799, Bias: -34.9992
# --------------------
# Epoch: 9, train loss: 69.6676
# Weight: 0.5863, Bias: -34.9992
# --------------------
# Epoch: 10, train loss: 57.1324
# Weight: 0.5917, Bias: -34.9992
# --------------------
# Epoch: 11, train loss: 48.5017
# Weight: 0.5961, Bias: -34.9991
# --------------------
# Epoch: 12, train loss: 42.5591
# Weight: 0.5997, Bias: -34.9991
# --------------------
# Epoch: 13, train loss: 38.4676
# Weight: 0.6028, Bias: -34.9991
# --------------------
# Epoch: 14, train loss: 35.6504
# Weight: 0.6053, Bias: -34.9991
# --------------------
# Epoch: 15, train loss: 33.7107
# Weight: 0.6074, Bias: -34.9991
# --------------------
# Epoch: 16, train loss: 32.3752
# Weight: 0.6091, Bias: -34.9991
# --------------------
# Epoch: 17, train loss: 31.4557
# Weight: 0.6106, Bias: -34.9990
# --------------------
# Epoch: 18, train loss: 30.8226
# Weight: 0.6118, Bias: -34.9990
# --------------------
# Epoch: 19, train loss: 30.3866
# Weight: 0.6127, Bias: -34.9990
# --------------------
# Epoch: 20, train loss: 30.0865
# Weight: 0.6136, Bias: -34.9990
# --------------------

# %%
# .grad 초기화 필요한 이유 실험
z = torch.tensor([1.],requires_grad=True)
for _ in range(2):
    loss = z**2
    loss.backward()
    print(z.grad)
    z.grad = torch.tensor([0.])
    # print(z.grad)
# Out:
# tensor([2.])
# tensor([2.])

# %%
# plot loss_history
plt.plot(range(1, EPOCH+1), loss_history)
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Training Loss")
# Out:
# Text(0.5, 1.0, 'Training Loss')

# %%
from torch import nn, optim

x=x.reshape(-1,1) # 개채 형태로 바꿔줌
y=y.reshape(-1,1) # x와 같은 형태로 바꿔줌 (MSELoss, BCELoss 는 y의 shape이 x의 shape과 같아야)

model=nn.Linear(1,1)
model.weight.data = torch.tensor([[0.45]])
model.bias.data = torch.tensor([-35.])

LR = 3e-6
EPOCH = 20
optimizer = optim.SGD(model.parameters(), lr=LR)
criterion = nn.MSELoss()

loss_history=[]

for ep in range(EPOCH):
    # inference
    y_hat = model(x)
    # loss
    loss = criterion(y_hat,y)
    # update
    optimizer.zero_grad() # gradient 누적을 막기 위한 초기화
    loss.backward() # backpropagation
    optimizer.step() # weight update
    # print loss
    loss_history += [loss.item()]
    print(f"Epoch: {ep+1}, train loss: {loss.item():.4f}")
    # print weight and bias
    print(f"Weight: {model.weight.data.item():.4f}, Bias: {model.bias.data.item():.4f}")
    # plot graph
    x_plot=torch.linspace(145,190,100)
    y_plot=model.weight.squeeze().detach() * x_plot + model.bias.detach()
    plt.figure()
    plt.plot(x,y,'o')
    plt.plot(x_plot,y_plot,'r')
    plt.title(f"Epoch {ep+1}")
    plt.show()

    print("-"*20)
# Out:
# Epoch: 1, train loss: 826.2250
# Weight: 0.4785, Bias: -34.9998
# --------------------
# Epoch: 2, train loss: 578.0414
# Weight: 0.5022, Bias: -34.9997
# --------------------
# Epoch: 3, train loss: 407.1602
# Weight: 0.5218, Bias: -34.9996
# --------------------
# Epoch: 4, train loss: 289.5042
# Weight: 0.5381, Bias: -34.9995
# --------------------
# Epoch: 5, train loss: 208.4954
# Weight: 0.5517, Bias: -34.9994
# --------------------
# Epoch: 6, train loss: 152.7187
# Weight: 0.5629, Bias: -34.9993
# --------------------
# Epoch: 7, train loss: 114.3153
# Weight: 0.5722, Bias: -34.9993
# --------------------
# Epoch: 8, train loss: 87.8735
# Weight: 0.5799, Bias: -34.9992
# --------------------
# Epoch: 9, train loss: 69.6676
# Weight: 0.5863, Bias: -34.9992
# --------------------
# Epoch: 10, train loss: 57.1324
# Weight: 0.5917, Bias: -34.9992
# --------------------
# Epoch: 11, train loss: 48.5017
# Weight: 0.5961, Bias: -34.9991
# --------------------
# Epoch: 12, train loss: 42.5591
# Weight: 0.5997, Bias: -34.9991
# --------------------
# Epoch: 13, train loss: 38.4676
# Weight: 0.6028, Bias: -34.9991
# --------------------
# Epoch: 14, train loss: 35.6504
# Weight: 0.6053, Bias: -34.9991
# --------------------
# Epoch: 15, train loss: 33.7107
# Weight: 0.6074, Bias: -34.9991
# --------------------
# Epoch: 16, train loss: 32.3752
# Weight: 0.6091, Bias: -34.9991
# --------------------
# Epoch: 17, train loss: 31.4557
# Weight: 0.6106, Bias: -34.9990
# --------------------
# Epoch: 18, train loss: 30.8225
# Weight: 0.6118, Bias: -34.9990
# --------------------
# Epoch: 19, train loss: 30.3866
# Weight: 0.6127, Bias: -34.9990
# --------------------
# Epoch: 20, train loss: 30.0865
# Weight: 0.6136, Bias: -34.9990
# --------------------

# %%
# plot loss_history
plt.plot(range(1, EPOCH+1), loss_history)
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Training Loss")
# Out:
# Text(0.5, 1.0, 'Training Loss')
